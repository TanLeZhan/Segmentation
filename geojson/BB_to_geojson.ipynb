# %%
building_tags = {
      "building": True,
      "man_made": ["pier"]}
water_tags = {
      "natural": [
          "water", "bay", "strait", "spring", "waterfall",
          "wetland", "glacier", "reef", "shoal"
      ],
      "waterway": [
          "river", "riverbank", "canal", "stream", "ditch",
          "drain", "weir", "lock_gate", "rapids", "tidal_channel"
      ],
      "landuse": [
          "reservoir", "basin", "harbour", "quay",
          "salt_pond", "fishpond", "aquaculture"
      ],
      "man_made": [
          "dock", "water_well", "water_tower",
          "wastewater_plant", "clarifier", "reservoir_covered"
      ]
  }
green_tags = {
    "natural": ["wood", "scrub", "grassland", "heath", "moor", "fell", "wetland"],
    "landuse": ["forest", "meadow", "grass", "village_green", "recreation_ground", "allotments"],
    "leisure": ["park", "garden", "nature_reserve", "golf_course", "pitch", "playground"]
  }
tags_dict = {
    "buildings": building_tags,
    "water": water_tags,
    "greenery": green_tags
}

# %%
import os
import osmnx
import geopandas as gpd
def generate_geodf(bbox, tags_dict, out_dir="geojson"):
    w, s, e, n = map(float, bbox.split(','))
    os.makedirs(out_dir, exist_ok=True)
    
    layers = {}
    for name, tags in tags_dict.items():
        try:
            gdf = osmnx.features_from_bbox((w, s, e, n), tags=tags).to_crs(4326) #3857 for meters, 4326 for lat/lon
            if not gdf.empty:
                out_path = f"{out_dir}/{name}.geojson"
                gdf.to_file(out_path, driver="GeoJSON")
                print(f"✅ Saved {out_path}")
            else:
                print(f"⚠️ No {name} features found in bbox.")
            layers[name] = gdf
        except Exception as e:
            print(f"❌ Error fetching {name}: {e}")
            layers[name] = gpd.GeoDataFrame(geometry=[], crs="EPSG:3857")
    
    return layers

# %%
bb_coords = "103.89813,1.41169,103.91346,1.42100"
generate_geodf(bb_coords, tags_dict)
# Out:
# ✅ Saved geojson/buildings.geojson
# ✅ Saved geojson/water.geojson
# ✅ Saved geojson/greenery.geojson
# {'buildings':                                                               geometry  \
#  element  id
#  node     4003708330                          POINT (103.90003 1.41224)
#  relation 7785498     POLYGON ((103.89905 1.41623, 103.89895 1.41628...
#           7785508     POLYGON ((103.89923 1.41214, 103.89923 1.41202...
#           14641460    POLYGON ((103.90064 1.41465, 103.90056 1.41449...
#           14641537    POLYGON ((103.90506 1.41851, 103.90507 1.41854...
#  ...                                                                ...
#  way      1283901253  POLYGON ((103.90864 1.4136, 103.90861 1.41361,...
#           1283901254  POLYGON ((103.91032 1.41463, 103.91035 1.41463...
#           1283901255  POLYGON ((103.90911 1.4145, 103.9096 1.41463, ...
#           1283901256  POLYGON ((103.91004 1.41499, 103.91007 1.41502...
#           1387540549  POLYGON ((103.90563 1.41545, 103.9055 1.41562,...
#
#                           building  addr:city addr:housenumber addr:postcode  \
#  element  id
#  node     4003708330  construction        NaN              NaN           NaN
#  relation 7785498              yes        NaN              NaN           NaN
#           7785508              yes        NaN              NaN           NaN
#           14641460         parking  Singapore              402        820402
#           14641537          school        NaN              NaN           NaN
#  ...                           ...        ...              ...           ...
#  way      1283901253        bridge        NaN              NaN           NaN
#           1283901254        bridge        NaN              NaN           NaN
#           1283901255        bridge        NaN              NaN           NaN
#           1283901256          roof        NaN              NaN           NaN
#           1387540549  kindergarten  Singapore              200        829646
#
#                                      addr:street denomination religion  \
#  element  id
#  node     4003708330                         NaN          NaN      NaN
#  relation 7785498                            NaN          NaN      NaN
#           7785508                            NaN          NaN      NaN
#           14641460              Northshore Drive          NaN      NaN
#           14641537                           NaN          NaN      NaN
#  ...                                         ...          ...      ...
#  way      1283901253                         NaN          NaN      NaN
#           1283901254                         NaN          NaN      NaN
#           1283901255                         NaN          NaN      NaN
#           1283901256                         NaN          NaN      NaN
#           1387540549  Ponggol Seventeenth Avenue          NaN      NaN
#
#                      building:levels layer  ...  \
#  element  id                                ...
#  node     4003708330             NaN   NaN  ...
#  relation 7785498                NaN   NaN  ...
#           7785508                NaN   NaN  ...
#           14641460               NaN   NaN  ...
#           14641537                 7   NaN  ...
#  ...                             ...   ...  ...
#  way      1283901253               5     1  ...
#           1283901254               5     2  ...
#           1283901255               5     1  ...
#           1283901256               4     1  ...
#           1387540549               1   NaN  ...
#
#                                                      description height  \
#  element  id
#  node     4003708330                                         NaN    NaN
#  relation 7785498                                            NaN    NaN
#           7785508                                            NaN    NaN
#           14641460                                           NaN    NaN
#           14641537                                           NaN    NaN
#  ...                                                         ...    ...
#  way      1283901253  Collaboration Loop (5th floor link bridge)    NaN
#           1283901254  Collaboration Loop (5th floor link bridge)    NaN
#           1283901255  Collaboration Loop (5th floor link bridge)    NaN
#           1283901256                5th floor link bridge/garden    NaN
#           1387540549                                         NaN    NaN
#
#                      min_height alt_name bench proposed          type  \
#  element  id
#  node     4003708330        NaN      NaN   NaN      NaN           NaN
#  relation 7785498           NaN      NaN   NaN      NaN  multipolygon
#           7785508           NaN      NaN   NaN      NaN  multipolygon
#           14641460          NaN      NaN   NaN      NaN  multipolygon
#           14641537          NaN      NaN   NaN      NaN  multipolygon
#  ...                        ...      ...   ...      ...           ...
#  way      1283901253        NaN      NaN   NaN      NaN           NaN
#           1283901254        NaN      NaN   NaN      NaN           NaN
#           1283901255        NaN      NaN   NaN      NaN           NaN
#           1283901256        NaN      NaN   NaN      NaN           NaN
#           1387540549        NaN      NaN   NaN      NaN           NaN
#
#                                           name:ms addr:housename level
#  element  id
#  node     4003708330                          NaN            NaN   NaN
#  relation 7785498                             NaN            NaN   NaN
#           7785508     Sekolah Rendah Punggol Cove            NaN   NaN
#           14641460                            NaN            NaN   NaN
#           14641537                            NaN            NaN   NaN
#  ...                                          ...            ...   ...
#  way      1283901253                          NaN            NaN   NaN
#           1283901254                          NaN            NaN   NaN
#           1283901255                          NaN            NaN   NaN
#           1283901256                          NaN            NaN   NaN
#           1387540549                          NaN            NaN   NaN
#
#  [349 rows x 50 columns],
#  'water':                                                              geometry natural  \
#  element id
#  way     163835785   POLYGON ((103.92185 1.39706, 103.92187 1.39732...   water
#          374844590   POLYGON ((103.91125 1.42101, 103.91128 1.42102...   water
#          1160692194  LINESTRING (103.92212 1.39737, 103.92158 1.397...     NaN
#
#                      water              name name:zh waterway
#  element id
#  way     163835785   canal               NaN     NaN      NaN
#          374844590    pond               NaN     NaN      NaN
#          1160692194    NaN  Punggol Waterway    榜鹅水道    canal  ,
#  'greenery':                                                               geometry  \
#  element id
#  node    8934992893                           POINT (103.89971 1.41315)
#          9737347773                           POINT (103.90091 1.41787)
#          10054719318                          POINT (103.90436 1.41958)
#          10054719319                          POINT (103.90471 1.41963)
#          10064839815                          POINT (103.90244 1.41671)
#  ...                                                                ...
#  way     1266083349   POLYGON ((103.91254 1.41793, 103.91256 1.41795...
#          1268414503   POLYGON ((103.91306 1.41847, 103.91311 1.41849...
#          1268414504   POLYGON ((103.91248 1.41851, 103.91249 1.41853...
#          1268414505   POLYGON ((103.91283 1.41936, 103.91285 1.41937...
#          1341686881   POLYGON ((103.9137 1.41501, 103.91315 1.41501,...
#
#                          leisure access level            name name:zh old_name  \
#  element id
#  node    8934992893   playground    NaN   NaN             NaN     NaN      NaN
#          9737347773   playground    yes   NaN             NaN     NaN      NaN
#          10054719318  playground    NaN   NaN             NaN     NaN      NaN
#          10054719319  playground    NaN   NaN             NaN     NaN      NaN
#          10064839815  playground    NaN     2             NaN     NaN      NaN
#  ...                         ...    ...   ...             ...     ...      ...
#  way     1266083349   playground    NaN   NaN             NaN     NaN      NaN
#          1268414503   playground    NaN   NaN             NaN     NaN      NaN
#          1268414504   playground    NaN   NaN             NaN     NaN      NaN
#          1268414505   playground    NaN   NaN             NaN     NaN      NaN
#          1341686881          NaN    NaN   NaN  Colonade Court     NaN      NaN
#
#                      wikidata wikipedia name:en website wikimedia_commons  \
#  element id
#  node    8934992893       NaN       NaN     NaN     NaN               NaN
#          9737347773       NaN       NaN     NaN     NaN               NaN
#          10054719318      NaN       NaN     NaN     NaN               NaN
#          10054719319      NaN       NaN     NaN     NaN               NaN
#          10064839815      NaN       NaN     NaN     NaN               NaN
#  ...                      ...       ...     ...     ...               ...
#  way     1266083349       NaN       NaN     NaN     NaN               NaN
#          1268414503       NaN       NaN     NaN     NaN               NaN
#          1268414504       NaN       NaN     NaN     NaN               NaN
#          1268414505       NaN       NaN     NaN     NaN               NaN
#          1341686881       NaN       NaN     NaN     NaN               NaN
#
#                      description landuse proposed natural layer sport barrier
#  element id
#  node    8934992893          NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          9737347773          NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          10054719318         NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          10054719319         NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          10064839815         NaN     NaN      NaN     NaN   NaN   NaN     NaN
#  ...                         ...     ...      ...     ...   ...   ...     ...
#  way     1266083349          NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          1268414503          NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          1268414504          NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          1268414505          NaN     NaN      NaN     NaN   NaN   NaN     NaN
#          1341686881          NaN   grass      NaN     NaN   NaN   NaN     NaN
#
#  [72 rows x 19 columns]}
